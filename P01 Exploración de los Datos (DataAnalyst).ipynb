# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
# %matplotlib inline

# %%
# Microdatos de DataAnalyst:https://www.kaggle.com/andrewmvd/data-analyst-jobs
path = 'DataAnalyst.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
df.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'Job Title',
#  'Salary Estimate',
#  'Job Description',
#  'Rating',
#  'Company Name',
#  'Location',
#  'Headquarters',
#  'Size',
#  'Founded',
#  'Type of ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Competitors',
#  'Easy Apply']

# %%
df.shape
# Out:
# (2253, 16)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.replace({'-1': np.nan}, inplace=True)

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Salary Estimate',
#  'Company Name',
#  'Headquarters',
#  'Size',
#  'Type of ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Competitors',
#  'Easy Apply']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                  0
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded                 0
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply           2173
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0       Rating      Founded
# count   2253.0000  2253.000000  2253.000000
# mean    1126.0000     3.160630  1398.522858
# std      650.5294     1.665228   901.929251
# min        0.0000    -1.000000    -1.000000
# 25%      563.0000     3.100000    -1.000000
# 50%     1126.0000     3.600000  1979.000000
# 75%     1689.0000     4.000000  2002.000000
# max     2252.0000     5.000000  2019.000000

# %%
df.loc[[0]]
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
#
#                      Company Name      Location  Headquarters  \
# 0  Vera Institute of Justice\n3.2  New York, NY  New York, NY
#
#                    Size  Founded       Type of ownership           Industry  \
# 0  201 to 500 employees     1961  Nonprofit Organization  Social Assistance
#
#        Sector                     Revenue Competitors Easy Apply
# 0  Non-Profit  $100 to $500 million (USD)         NaN       True

# %%
df[["Job Title", "Salary Estimate","Easy Apply"]].loc[[200]]
# Out:
#                Job Title              Salary Estimate Easy Apply
# 200  SENIOR DATA ANALYST  $60K-$110K (Glassdoor est.)        NaN

# %%
df.drop(['Unnamed: 0'], axis=1).head(10)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
# 5                                       Data Analyst
# 6                       Business/Data Analyst (FP&A)
# 7                               Data Science Analyst
# 8                                       Data Analyst
# 9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# 6  $37K-$66K (Glassdoor est.)
# 7  $37K-$66K (Glassdoor est.)
# 8  $37K-$66K (Glassdoor est.)
# 9  $37K-$66K (Glassdoor est.)
#
# ...

# %%
df.loc[30:33]
# Out:
#     Unnamed: 0                              Job Title  \
# 30          30                           Data Analyst
# 31          31                           Data Analyst
# 32          32                           Data Analyst
# 33          33  Data Science Analyst, Capital Markets
#
#                Salary Estimate  \
# 30  $46K-$87K (Glassdoor est.)
# 31  $46K-$87K (Glassdoor est.)
# 32  $46K-$87K (Glassdoor est.)
# 33  $46K-$87K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 30  Our Mission\n\nMove people.\n\nOur Values\n\nW...     3.6
# 31  Data Analyst Jersey City, NJ 12+ months contra...     3.6
# 32  Job Description:\nLegal experience is required...     3.5
# 33  Who we are\n\nSoFi is a digital personal finan...     3.2
#
#                Company Name         Location       Headquarters  \
# 30               Revel\n3.6     Brooklyn, NY        Seattle, WA
# 31  NALLAS CORPORATION\n3.6  Jersey City, NJ        Newtown, PA
# ...

# %%
df.drop(df.index[2:5], axis=0).head(10)
# Out:
#     Unnamed: 0                                          Job Title  \
# 0            0  Data Analyst, Center on Immigration and Justic...
# 1            1                               Quality Data Analyst
# 5            5                                       Data Analyst
# 6            6                       Business/Data Analyst (FP&A)
# 7            7                               Data Science Analyst
# 8            8                                       Data Analyst
# 9            9                      Data Analyst, Merchant Health
# 10          10                                       Data Analyst
# 11          11                                       Data Analyst
# 12          12                                       DATA ANALYST
#
#                Salary Estimate  \
# 0   $37K-$66K (Glassdoor est.)
# 1   $37K-$66K (Glassdoor est.)
# 5   $37K-$66K (Glassdoor est.)
# 6   $37K-$66K (Glassdoor est.)
# 7   $37K-$66K (Glassdoor est.)
# 8   $37K-$66K (Glassdoor est.)
# ...

# %%
df.Industry.values
# Out:
# array(['Social Assistance', 'Health Care Services & Hospitals',
#        'Internet', ..., nan, 'Enterprise Software & Network Solutions',
#        'Health Care Services & Hospitals'], dtype=object)

# %%
df.Industry.unique()
# Out:
# array(['Social Assistance', 'Health Care Services & Hospitals',
#        'Internet', 'IT Services', 'Sports & Recreation',
#        'Investment Banking & Asset Management', 'Insurance Carriers',
#        'Venture Capital & Private Equity', 'Research & Development', nan,
#        'Advertising & Marketing', 'Brokerage Services',
#        'Building & Personnel Services', 'Consulting',
#        'Casual Restaurants', 'Enterprise Software & Network Solutions',
#        'Lending', 'Banks & Credit Unions', 'Computer Hardware & Software',
#        'Staffing & Outsourcing',
#        'Motion Picture Production & Distribution', 'Legal', 'Real Estate',
#        'Federal Agencies', 'TV Broadcast & Cable Networks', 'Accounting',
#        'Food & Beverage Stores', 'Health, Beauty, & Fitness',
#        'Biotech & Pharmaceuticals', 'Insurance Agencies & Brokerages',
#        'Gambling', 'Video Games', 'Colleges & Universities',
#        'Architectural & Engineering Services',
# ...

# %%
df.Location.values
# Out:
# array(['New York, NY', 'New York, NY', 'New York, NY', ..., 'Denver, CO',
#        'Centennial, CO', 'Broomfield, CO'], dtype=object)

# %%
df.Location.unique()
# Out:
# array(['New York, NY', 'Fairfield, NJ', 'Jersey City, NJ', 'Brooklyn, NY',
#        'Weehawken, NJ', 'Long Island City, NY', 'Florham Park, NJ',
#        'Manhasset, NY', 'Newark, NJ', 'Queens Village, NY', 'Haworth, NJ',
#        'Fort Lee, NJ', 'South Plainfield, NJ', 'Bronx, NY',
#        'Little Ferry, NJ', 'Lake Success, NY', 'Summit, NJ',
#        'Valley Stream, NY', 'Berkeley Heights, NJ', 'Essex Fells, NJ',
#        'Franklin Lakes, NJ', 'Mount Vernon, NY', 'Secaucus, NJ',
#        'West Orange, NJ', 'Far Rockaway, NY', 'Woodbridge, NJ',
#        'Parsippany, NJ', 'Whippany, NJ', 'Great Neck, NY', 'Hoboken, NJ',
#        'Staten Island, NY', 'Harrison, NY', 'Iselin, NJ', 'Montvale, NJ',
#        'Woodcliff Lake, NJ', 'Salt Lake City, UT', 'West Jordan, UT',
#        'Lehi, UT', 'Draper, UT', 'American Fork, UT', 'Sandy, UT',
#        'Riverton, UT', 'Reedley, CA', 'Visalia, CA', 'Hanford, CA',
#        'Hampton, VA', 'Norfolk, VA', 'Portsmouth, VA', 'Chesapeake, VA',
# ...

# %%
df.Rating.unique()
# Out:
# array([ 3.2,  3.8,  3.4,  4.1,  3.9,  4.4,  3.7,  4. , -1. ,  3. ,  3.6,
#         4.9,  3.3,  3.5,  5. ,  4.8,  4.7,  4.6,  2.9,  1. ,  3.1,  4.5,
#         2.3,  4.2,  2.8,  4.3,  2.7,  2.5,  2.6,  2.4,  2. ,  2.1,  1.7,
#         2.2,  1.8,  1.6,  1.9])

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          Unnamed: 0  Job Title  Salary Estimate  Job Description  Rating  \
# count          2253       2253             2252             2253    2253
# size           2253       2253             2253             2253    2253
# nunique        2253       1272               89             2253      37
#
#          Company Name  Location  Headquarters  Size  Founded  \
# count            2252      2253          2081  2090     2253
# size             2253      2253          2253  2253     2253
# nunique          1513       253           482     8      161
#
#          Type of ownership  Industry  Sector  Revenue  Competitors  Easy Apply
# count                 2090      1900    1900     2090          521          80
# size                  2253      2253    2253     2253         2253        2253
# nunique                 14        88      24       13          290           1

# %%
df.groupby('Industry').agg(['count', 'size', 'nunique']).stack()
# Out:
#                                  Unnamed: 0  Job Title  Salary Estimate  \
# Industry
# Accounting              count            39         39               39
#                         size             39         39               39
#                         nunique          39         29               31
# Advertising & Marketing count            51         51               51
#                         size             51         51               51
# ...                                     ...        ...              ...
# Video Games             size             20         20               20
#                         nunique          20         11               17
# Wholesale               count             6          6                6
#                         size              6          6                6
#                         nunique           6          5                5
#
#                                  Job Description  Rating  Company Name  \
# Industry
# ...

# %% [markdown]
# ## Transformacion de los datos

# %%
df_dropped = df.drop(['Unnamed: 0'], axis=1)
df_dropped.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %% [markdown]
# ## Visualizacion de los Datos

# %%
df.Industry
# Out:
# 0                             Social Assistance
# 1              Health Care Services & Hospitals
# 2                                      Internet
# 3                                   IT Services
# 4                           Sports & Recreation
#                          ...
# 2248                     Staffing & Outsourcing
# 2249                                  Wholesale
# 2250                                        NaN
# 2251    Enterprise Software & Network Solutions
# 2252           Health Care Services & Hospitals
# Name: Industry, Length: 2253, dtype: object

# %%
df.groupby("Industry").count()
# Out:
#                                       Unnamed: 0  Job Title  Salary Estimate  \
# Industry
# Accounting                                    39         39               39
# Advertising & Marketing                       51         51               51
# Aerospace & Defense                           22         22               22
# Architectural & Engineering Services          13         13               13
# Audiovisual                                    1          1                1
# ...                                          ...        ...              ...
# Utilities                                      2          2                2
# Vehicle Dealers                                3          3                3
# Venture Capital & Private Equity               6          6                6
# Video Games                                   20         20               20
# Wholesale                                      6          6                6
#
# ...

# %%
df.groupby(["Sector"])[["Job Title"]].count()
# Out:
#                                     Job Title
# Sector
# Accounting & Legal                         43
# Aerospace & Defense                        22
# Arts, Entertainment & Recreation            7
# Biotech & Pharmaceuticals                  33
# Business Services                         524
# Construction, Repair & Maintenance         16
# Consumer Services                          14
# Education                                  52
# Finance                                   169
# Government                                 36
# Health Care                               151
# Information Technology                    570
# Insurance                                  51
# Manufacturing                              40
# Media                                      42
# Mining & Metals                             1
# Non-Profit                                 26
# Oil, Gas, Energy & Utilities               13
# Real Estate                                12
# ...

# %%
df_bar=df.groupby(["Sector"])[["Job Title"]].count()
df_bar.plot(kind='bar')
